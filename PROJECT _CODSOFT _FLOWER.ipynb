# %% [markdown]
# Aryan Zende
#
# <h1 style='text-align:center;'>CODSOFT</h1> <h3 style='text-align:center;'>DATA SCIENCE</h3> <h4 style='text-align:center;'>Iris Flower Classification using Machine Learning</h4> <p style='text-align:center;'>Analyze the Iris flower dataset to classify species (Setosa, Versicolor, Virginica) based on features like sepal length, sepal width, petal length, and petal width.</p>

# %%
import warnings
import joblib
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
from sklearn import metrics

# %%
iris=load_iris()
X=pd.DataFrame(iris.data,columns=iris.feature_names)
y=pd.Categorical.from_codes(iris.target,iris.target_names)

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# ['setosa', 'setosa', 'setosa', 'setosa', 'setosa', ..., 'virginica', 'virginica', 'virginica', 'virginica', 'virginica']
# Length: 150
# Categories (3, object): ['setosa', 'versicolor', 'virginica']

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
X.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
pd.get_dummies(y)
# Out:
#      setosa  versicolor  virginica
# 0      True       False      False
# 1      True       False      False
# 2      True       False      False
# 3      True       False      False
# 4      True       False      False
# ..      ...         ...        ...
# 145   False       False       True
# 146   False       False       True
# 147   False       False       True
# 148   False       False       True
# 149   False       False       True
#
# [150 rows x 3 columns]

# %%
y
# Out:
# ['setosa', 'setosa', 'setosa', 'setosa', 'setosa', ..., 'virginica', 'virginica', 'virginica', 'virginica', 'virginica']
# Length: 150
# Categories (3, object): ['setosa', 'versicolor', 'virginica']

# %%
pd.get_dummies(y)
# Out:
#      setosa  versicolor  virginica
# 0      True       False      False
# 1      True       False      False
# 2      True       False      False
# 3      True       False      False
# 4      True       False      False
# ..      ...         ...        ...
# 145   False       False       True
# 146   False       False       True
# 147   False       False       True
# 148   False       False       True
# 149   False       False       True
#
# [150 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
from sklearn import tree
fig=plt.figure(figsize=(25,20))
_=tree.plot_tree(dt,feature_names=iris.feature_names,
                 class_names=iris.target_names,
                 filled=True)

# %%
y_pred=dt.predict(X_test)

# %%
species=np.array(y_test).argmax()
predictions=np.array(y_pred).argmax()
species = y_test
predictions = y_pred

confusion_matrix(species,predictions)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]], dtype=int64)

# %% [markdown]
# Jaccard Index
# F1-Score
# Log loss

# %%
from sklearn.metrics import classification_report

# Assuming y_test and y_pred contain the true and predicted labels
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      0.94      0.97        16
#    virginica       0.90      1.00      0.95         9
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.98      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Iris Classification Model Summary
#
# The objective of this project is to classify Iris flowers into three species (Setosa, Versicolor, Virginica) based on their sepal and petal measurements. The Iris dataset, a popular choice for introductory classification tasks, is used for training and testing the model.
#
# ## Steps Involved
#
# 1. **Load the Dataset**: Import the dataset using `scikit-learn`.
# 2. **Split the Data**: Divide the data into training and testing sets for model evaluation.
# 3. **Data Preprocessing**: Standardize the feature values to improve model accuracy.
# 4. **Model Selection**: Use the K-Nearest Neighbors (KNN) algorithm, a simple and effective classification model.
# 5. **Train the Model**: Fit the KNN model on the training dataset.
# 6. **Make Predictions**: Use the test data to assess the model’s ability to generalize.
# 7. **Evaluate the Model**: Evaluate using metrics such as accuracy, classification report, and confusion matrix.
